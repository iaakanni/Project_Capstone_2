# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
file_path = r'C:\Users\isaac\OneDrive\Desktop\Project_Capstone 2\Project_Capstone_2\dataset\rawdata\Sales Dataset - Sales Dataset.csv'

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-26776    9726    1275         5  Electronics  Electronic Games
# 1  B-26776    9726    1275         5  Electronics  Electronic Games
# 2  B-26776    9726    1275         5  Electronics  Electronic Games
# 3  B-26776    4975    1330        14  Electronics          Printers
# 4  B-26776    4975    1330        14  Electronics          Printers
#
#   PaymentMode  Order Date   CustomerName     State     City Year-Month
# 0         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 1         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2         UPI  2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 4         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12

# %%
df.columns = df.columns.str.replace(" ", "_").str.strip()
df.columns = df.columns.str.replace("PaymentMode", "Payment_Mode").str.strip()
df.columns = df.columns.str.replace("CustomerName", "Customer_Name").str.strip()
df.columns = df.columns.str.replace("Year-Month", "Year_Month").str.strip()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      1194 non-null   object
#  1   Amount        1194 non-null   int64
#  2   Quantity      1194 non-null   int64
#  3   Profit        1194 non-null   int64
#  4   Order_Date    1194 non-null   datetime64[ns]
#  5   Payment_Mode  1194 non-null   object
#  6   Customer_ID   1194 non-null   int64
#  7   Products_ID   1194 non-null   int64
#  8   Location_ID   1194 non-null   int64
#  9   Date_ID       1194 non-null   int64
# dtypes: datetime64[ns](1), int64(7), object(2)
# memory usage: 93.4+ KB

# %%
df.head()
# Out:
#   Order_ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-26776    9726    1275         5  Electronics  Electronic Games
# 1  B-26776    9726    1275         5  Electronics  Electronic Games
# 2  B-26776    9726    1275         5  Electronics  Electronic Games
# 3  B-26776    4975    1330        14  Electronics          Printers
# 4  B-26776    4975    1330        14  Electronics          Printers
#
#   Payment_Mode  Order_Date  Customer_Name     State     City Year_Month
# 0          UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 1          UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2          UPI  2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3          UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 4          UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12

# %%
# convert Order_Date to datetime\n"

df["Order_Date"] = pd.to_datetime(df["Order_Date"])
#df["Year_Month"] = df["Order_Date"].dt.to_period("M")
Date['Year_Month'] = Date['Year_Month'].astype(str)

# %%
df.head()
# Out:
#   Order_ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-26776    9726    1275         5  Electronics  Electronic Games
# 1  B-26776    9726    1275         5  Electronics  Electronic Games
# 2  B-26776    9726    1275         5  Electronics  Electronic Games
# 3  B-26776    4975    1330        14  Electronics          Printers
# 4  B-26776    4975    1330        14  Electronics          Printers
#
#   Payment_Mode Order_Date  Customer_Name     State     City Year_Month
# 0          UPI 2023-06-27  David Padilla   Florida    Miami    2023-06
# 1          UPI 2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2          UPI 2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3          UPI 2023-06-27  David Padilla   Florida    Miami    2023-06
# 4          UPI 2024-12-27  Connor Morgan  Illinois  Chicago    2024-12

# %%
#Reset to avoid not being continous
df = df.reset_index(drop=True)
df["Order_ID"] = "OID-" + (10001 + df.index).astype(str)

# %%
df.head()
# Out:
#     Order_ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  OID-10001    9726    1275         5  Electronics  Electronic Games
# 1  OID-10002    9726    1275         5  Electronics  Electronic Games
# 2  OID-10003    9726    1275         5  Electronics  Electronic Games
# 3  OID-10004    4975    1330        14  Electronics          Printers
# 4  OID-10005    4975    1330        14  Electronics          Printers
#
#   Payment_Mode Order_Date  Customer_Name     State     City Year_Month
# 0          UPI 2023-06-27  David Padilla   Florida    Miami    2023-06
# 1          UPI 2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2          UPI 2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3          UPI 2023-06-27  David Padilla   Florida    Miami    2023-06
# 4          UPI 2024-12-27  Connor Morgan  Illinois  Chicago    2024-12

# %%
# Create new CustomerID column
df["Customer_ID"] = range(1001, 1001 + len(df))
df["Product_ID"] = range(1001, 1001 + len(df))

# Preview
df.head()
# Out:
#     Order_ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  OID-10001    9726    1275         5  Electronics  Electronic Games
# 1  OID-10002    9726    1275         5  Electronics  Electronic Games
# 2  OID-10003    9726    1275         5  Electronics  Electronic Games
# 3  OID-10004    4975    1330        14  Electronics          Printers
# 4  OID-10005    4975    1330        14  Electronics          Printers
#
#   Payment_Mode Order_Date  Customer_Name     State     City Year_Month  \
# 0          UPI 2023-06-27  David Padilla   Florida    Miami    2023-06
# 1          UPI 2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2          UPI 2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3          UPI 2023-06-27  David Padilla   Florida    Miami    2023-06
# 4          UPI 2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
#
#    Customer_ID  Product_ID
# 0         1001        1001
# 1         1002        1002
# 2         1003        1003
# ...

# %%
df = df.reset_index(drop=True)
df["Customer_ID"] = "CID-" + (10001 + df.index).astype(str)
df["Product_ID"] = "PID-" + (10001 + df.index).astype(str)
df["Location_ID"] = "LID-" + (10001 + df.index).astype(str)
df["Date_ID"] = "DID-" + (10001 + df.index).astype(str)
df.head()
# Out:
#     Order_ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  OID-10001    9726    1275         5  Electronics  Electronic Games
# 1  OID-10002    9726    1275         5  Electronics  Electronic Games
# 2  OID-10003    9726    1275         5  Electronics  Electronic Games
# 3  OID-10004    4975    1330        14  Electronics          Printers
# 4  OID-10005    4975    1330        14  Electronics          Printers
#
#   Payment_Mode Order_Date  Customer_Name     State     City Year_Month  \
# 0          UPI 2023-06-27  David Padilla   Florida    Miami    2023-06
# 1          UPI 2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2          UPI 2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3          UPI 2023-06-27  David Padilla   Florida    Miami    2023-06
# 4          UPI 2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
#
#   Customer_ID Product_ID Location_ID    Date_ID
# 0   CID-10001  PID-10001   LID-10001  DID-10001
# ...

# %%
df.tail()
# Out:
#        Order_ID  Amount  Profit  Quantity         Category Sub-Category  \
# 1189  OID-11190    8825    3594        15        Furniture       Tables
# 1190  OID-11191    2082     642         8      Electronics       Phones
# 1191  OID-11192    2082     642         8      Electronics       Phones
# 1192  OID-11193    2082     642         8      Electronics       Phones
# 1193  OID-11194     914     163        13  Office Supplies      Markers
#
#      Payment_Mode Order_Date       Customer_Name     State           City  \
# 1189   Debit Card 2024-07-31        Megan Mclean  New York  New York City
# 1190          EMI 2020-06-02        Caitlin Hunt  New York      Rochester
# 1191          EMI 2022-12-15       Jenna Holland     Texas         Austin
# 1192          EMI 2020-08-07  Stephanie Oconnell  New York        Buffalo
# 1193          UPI 2024-10-26         Andrea Hill  Illinois        Chicago
#
#      Year_Month Customer_ID Product_ID Location_ID    Date_ID
# ...

# %%
# Derive year, month, quarter, date_id for dim_date
df["Year"]    = df["Order_Date"].dt.year
df["Month"]   = df["Order_Date"].dt.month
df["Quarter"] = df["Order_Date"].dt.quarter

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       1194 non-null   object
#  1   Amount         1194 non-null   int64
#  2   Profit         1194 non-null   int64
#  3   Quantity       1194 non-null   int64
#  4   Category       1194 non-null   object
#  5   Sub-Category   1194 non-null   object
#  6   Payment_Mode   1194 non-null   object
#  7   Order_Date     1194 non-null   datetime64[ns]
#  8   Customer_Name  1194 non-null   object
#  9   State          1194 non-null   object
#  10  City           1194 non-null   object
#  11  Year_Month     1194 non-null   period[M]
#  12  Customer_ID    1194 non-null   object
#  13  Product_ID     1194 non-null   object
#  14  Location_ID    1194 non-null   object
#  15  Date_ID        1194 non-null   object
#  16  Year           1194 non-null   int32
# ...

# %%
df.head()
# Out:
#     Order_ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  OID-10001    9726    1275         5  Electronics  Electronic Games
# 1  OID-10002    9726    1275         5  Electronics  Electronic Games
# 2  OID-10003    9726    1275         5  Electronics  Electronic Games
# 3  OID-10004    4975    1330        14  Electronics          Printers
# 4  OID-10005    4975    1330        14  Electronics          Printers
#
#   Payment_Mode Order_Date  Customer_Name     State     City Year_Month  \
# 0          UPI 2023-06-27  David Padilla   Florida    Miami    2023-06
# 1          UPI 2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2          UPI 2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3          UPI 2023-06-27  David Padilla   Florida    Miami    2023-06
# 4          UPI 2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
#
#   Year_Month Customer_ID Product_ID Location_ID    Date_ID  Year  Month  \
# ...

# %%
# Drop duplicates & nulls
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# %% [markdown]
# #### ── TRANSFORMATIONS ────────────────────────────────────────────────────────

# %%
# ── 3. TRANSFORMATIONS ────────────────────────────────────────────────────────

# Monthly profit aggregation
monthly_profit = (
    df.groupby('Year_Month')['Profit']
    .sum()
    .reset_index()
    .rename(columns={'Profit': 'Total_Profit'})
    .sort_values('Year_Month')
)

# Top 10 customers by total amount
top_customers = (
    df.groupby('Customer_Name')['Amount']
    .sum()
    .reset_index()
    .rename(columns={'Amount': 'Total_Amount'})
    .sort_values('Total_Amount', ascending=False)
    .head(10)
)

# Quantity sold per category
qty_per_category = (
    df.groupby('Category')['Quantity']
    .sum()
    .reset_index()
    .rename(columns={'Quantity': 'Total_Quantity'})
    .sort_values('Total_Quantity', ascending=False)
)

# Cities with low profitability (below median profit)
city_profit = (
    df.groupby('City')['Profit']
    .sum()
    .reset_index()
    .rename(columns={'Profit': 'Total_Profit'})
)
median_profit = city_profit['Total_Profit'].median()
low_profit_cities = city_profit[city_profit['Total_Profit'] < median_profit].sort_values('Total_Profit')

# ── 4. WRITE TO CSV ───────────────────────────────────────────────────────────
df.to_csv('Cleaned_Sales.csv', index=False)
monthly_profit.to_csv('Monthly_Profit.csv', index=False)
top_customers.to_csv('Top_Customers.csv', index=False)
qty_per_category.to_csv('Qty_Per_Category.csv', index=False)
low_profit_cities.to_csv('Low_Profit_Cities.csv', index=False)

print("Done. Files written:")
print("  Cleaned_Sales.csv, Monthly_Profit.csv, Top_Customers.csv, Qty_Per_Category.csv, Low_Profit_Cities.csv")
# Out:
# Done. Files written:
#   Cleaned_Sales.csv, Monthly_Profit.csv, Top_Customers.csv, Qty_Per_Category.csv, Low_Profit_Cities.csv

# %%
cleaned_sales    = pd.read_csv('cleaned_sales.csv')
monthly_profit   = pd.read_csv('monthly_profit.csv')
top_customers    = pd.read_csv('top_customers.csv')
qty_per_category = pd.read_csv('qty_per_category.csv')
low_profit_cities = pd.read_csv('low_profit_cities.csv')

print("=== Cleaned Sales ===")
print(cleaned_sales.head())
# Out:
# === Cleaned Sales ===
#     Order_ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  OID-10001    9726    1275         5  Electronics  Electronic Games
# 1  OID-10002    9726    1275         5  Electronics  Electronic Games
# 2  OID-10003    9726    1275         5  Electronics  Electronic Games
# 3  OID-10004    4975    1330        14  Electronics          Printers
# 4  OID-10005    4975    1330        14  Electronics          Printers
#
#   Payment_Mode  Order_Date     State     City Year_Month  Customer_Name  \
# 0          UPI  2023-06-27   Florida    Miami    2023-06  David Padilla
# 1          UPI  2024-12-27  Illinois  Chicago    2024-12  Connor Morgan
# 2          UPI  2021-07-25  New York  Buffalo    2021-07   Robert Stone
# 3          UPI  2023-06-27   Florida    Miami    2023-06  David Padilla
# 4          UPI  2024-12-27  Illinois  Chicago    2024-12  Connor Morgan
#
#   Customer_ID Product_ID Location_ID    Date_ID Year-Month  Year  Month  \
# ...

# %%
print("\n=== Monthly Profit ===")
print(monthly_profit)
# Out:
# === Monthly Profit ===
#    Year_Month  Total_Profit
# 0     2020-03          6192
# 1     2020-04         36156
# 2     2020-05         24294
# 3     2020-06          9489
# 4     2020-07         12008
# ..        ...           ...
# 56    2024-11         15657
# 57    2024-12         20981
# 58    2025-01         38595
# 59    2025-02         28151
# 60    2025-03         13497
#
# [61 rows x 2 columns]

# %%
print("\n=== Top Customers ===")
print(top_customers)
# Out:
# === Top Customers ===
#         Customer_Name  Total_Amount
# 0          Cory Evans         28557
# 1       Emily Ellison         27352
# 2       George Foster         27352
# 3   Nicholas Anderson         27352
# 4  Katherine Williams         25121
# 5   Jacqueline Harris         24433
# 6       Randy Johnson         24295
# 7          Tammy Bell         23895
# 8         Brian Green         23737
# 9       Zachary Perez         23737

# %%
print("\n=== Quantity per Category ===")
print(qty_per_category)
# Out:
# === Quantity per Category ===
#           Category  Total_Quantity
# 0        Furniture            4441
# 1      Electronics            4258
# 2  Office Supplies            4046

# %%
print("\n=== Low Profit Cities ===")
print(low_profit_cities)
# Out:
# === Low Profit Cities ===
#           City  Total_Profit
# 0     Columbus         56277
# 1  Los Angeles         69264
# 2        Tampa         70842
# 3      Houston         72659
# 4       Peoria         76106
# 5   Cincinnati         78788
# 6      Chicago         80061
# 7    Cleveland         81454
# 8       Austin         82638

# %%
df.columns
# Out:
# Index(['Order_ID', 'Amount', 'Profit', 'Quantity', 'Category', 'Sub-Category',
#        'Payment_Mode', 'Order_Date', 'State', 'City', 'Year_Month',
#        'Customer_Name', 'Customer_ID', 'Product_ID', 'Location_ID', 'Date_ID',
#        'Year-Month', 'Year', 'Month', 'Quarter'],
#       dtype='object')

# %%
# Customers
Customers = df[['Customer_Name', 'City', 'State']].reset_index(drop=True)  
Customers['Customer_ID'] = Customers.index + 1  
Customers = Customers[['Customer_ID', 'Customer_Name', 'City', 'State']]

# %%
#Products
Products = df[['Category', 'Sub-Category']].reset_index(drop=True)
Products['Products_ID'] = Products.index + 1
Products = Products[['Products_ID', 'Category', 'Sub-Category']]

# %%
#Location
Location = df[['City', 'State']].reset_index(drop=True)
Location['Location_ID'] = Location.index + 1
Location = Location[['Location_ID', 'City', 'State']]

# %%
#Date
Date = df[['Order_Date', 'Year_Month', 'Year', 'Month', 'Quarter']].reset_index(drop=True)
Date['Date_ID'] = Date.index + 1
Date = Date[['Date_ID', 'Order_Date', 'Year_Month', 'Year', 'Month', 'Quarter']]

# %%
#Orders Fact
Orders_Fact = df[['Order_ID', 'Amount', 'Quantity', 'Profit', 'Order_Date', 'Payment_Mode']].reset_index(drop=True)
Orders_Fact['Customer_ID'] = Customers['Customer_ID']
Orders_Fact['Products_ID'] = Products['Products_ID']
Orders_Fact['Location_ID'] = Location['Location_ID']
Orders_Fact['Date_ID'] = Date['Date_ID']
#Orders_Fact['Order_ID'] = Orders.index + 1
#Orders_Fact = Orders[['Order_ID', 'Customer_ID', 'Product_ID', 'Location_ID', 'Date_ID', 'Amount', 'Quantity', 'Profit', 'Order_Date', 'Payment_Mode']]

# %%
#Temporary storage
Customers.to_csv('processed_data/Customers.csv', index=False)
Products.to_csv('processed_data/Products.csv', index=False)
Location.to_csv('processed_data/Location.csv', index=False)
Date.to_csv('processed_data/Date.csv', index=False)
Orders_Fact.to_csv('processed_data/Orders_Fact.csv', index=False)

# %%
#Database Storage
# !pip install psycopg2 sqlalchemy

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
db_config = {
    "user": "postgres",
    "password": "Akanni123@",
    "host": "localhost",
    "port": "5432",
    "database": "National_Data"
}

database_url = f"postgresql://{db_config["user"]}:{db_config["password"]}@{db_config["host"]}:{db_config["port"]}/{db_config["database"]}"

# %%
engine = create_engine(database_url)

# %%
Customers.to_sql('Customers', engine, if_exists='replace', index=False)
Products.to_sql('Products', engine, if_exists='replace', index=False)
Location.to_sql('Location', engine, if_exists='replace', index=False)
Date.to_sql('Date', engine, if_exists='replace', index=False)
Orders_Fact.to_sql('Orders_Fact', engine, if_exists='replace', index=False)

print("All tables saved to PostgreSQL!")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3301, in Engine.raw_connection(self)
#    3280 """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282 The returned object is a proxied version of the DBAPI
#    (...)   3299
#    3300 """
# -> 3301 return self.pool.connect()
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
#     441
#     442 The connection is instrumented such that when its
# ...

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# Create engine with 127.0.0.1 (not localhost)
password = quote_plus("Akanni123@")  # put your exact password here
engine = create_engine(f"postgresql+psycopg2://postgres:{password}@127.0.0.1:5432/National_Data")

# Test first
with engine.connect() as conn:
    print("Connected!")

# Fix Period column
Date['Year_Month'] = Date['Year_Month'].astype(str)

# Save all tables
Customers.to_sql('customers', engine, if_exists='replace', index=False)
Products.to_sql('products', engine, if_exists='replace', index=False)
Location.to_sql('locations', engine, if_exists='replace', index=False)
Date.to_sql('dates', engine, if_exists='replace', index=False)
Orders_Fact.to_sql('orders_fact', engine, if_exists='replace', index=False)

print("All tables saved to PostgreSQL!")
# Out:
# Connected!
# All tables saved to PostgreSQL!
